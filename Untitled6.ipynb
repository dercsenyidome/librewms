# %% [markdown]
# <a href="https://colab.research.google.com/github/dercsenyidome/librewms/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# --- A TE ADATAID ---
TELEGRAM_TOKEN = "8564500798:AAF5EYstCLgf4xbW6YR2tsfnKkv--Iqp-gg"
TELEGRAM_CHAT_ID = "8437667618"

def test_telegram():
    print("📨 Teszt üzenet küldése...")

    message = "🔔 Szia! Ez egy TESZT üzenet a Sniper Botodtól. A kapcsolat működik!"

    url = f"https://api.telegram.org/bot{TELEGRAM_TOKEN}/sendMessage"
    data = {
        "chat_id": TELEGRAM_CHAT_ID,
        "text": message
    }

    try:
        response = requests.post(url, data=data)

        if response.status_code == 200:
            print("✅ SIKER! Nézd meg a telefonodat, meg kellett érkeznie.")
        else:
            print(f"❌ HIBA: A Telegram elutasította. Kód: {response.status_code}")
            print(f"Válasz: {response.text}")
            print("Tipp: Írtál már '/start'-ot a botnak privátban?")

    except Exception as e:
        print(f"⚠️ Hiba a kapcsolódáskor: {e}")

if __name__ == "__main__":
    test_telegram()
# Out:
# 📨 Teszt üzenet küldése...
# ✅ SIKER! Nézd meg a telefonodat, meg kellett érkeznie.
